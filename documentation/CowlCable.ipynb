# %%
from pyknit import stitch_legend, parse_chart, plot_chart

# %% [markdown]
# This is a demo of the chart plotting function using the stitch library to draw a cable pattern. I haven't knitted the pattern yet, but it will form a border element on a cowl I'm starting just now :)

# %%
instructions = "\n".join([
    "p2 k2 p2 k2 p2",
    "p2 C2-1PL C2-1PR p2",
    "p3 k4 p3",
    "p3 C2-2R p3",
    "p3 k4 p3",
    "p2 C2-1PR C2-1PL p2",
    "p2 k2 p2 k2 p2",
    "p2 C2-1PL C2-1PR p2",
    "p3 k4 p3",
    "p3 C2-2L p3",
    "p3 k4 p3",
    "p2 C2-1PR C2-1PL p2",
    "p2 k2 p2 k2 p2",
])
patt = parse_chart(instructions, legend=stitch_legend)

plot_chart(patt, tb_direction= "bt", lr_direction="rl")
# Out:
# 13 rows, 10 sts wide at max
# <PIL.Image.Image image mode=RGB size=550x700>
